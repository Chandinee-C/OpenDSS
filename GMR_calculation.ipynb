# %% [markdown]
# # Assignment 3
# ### ---Chandinee C
# Calculate the GMR for the following two geometries in terms of $r$

# %% [markdown]
# ## CONFIGURATION 1

# %% [markdown]
# four strands each rith radius $r$ layed out in a square configuration
#
# ![image.png](attachment:image.png)

# %%
import math
r = 1
n=4
D11 = D22 = D33 = D44 = 0.7788 * r # Self GMR
D12 = D13 = D14 = 2 * r 
D21 = D23 = D24 = 2 * r
D31 = D32 = D34 = 2 * r
D41 = D42 = D43 = 2 * r

# %%
GMR = math.pow((D11 * D12 * D13 * D14) * (D21 * D22 * D23 * D24) * (D31 * D32 * D33 * D34) * (D41 * D42 * D43 * D44) , 1/(n**2))
GMR
# Out:
# 1.5798977567841632

# %% [markdown]
# GMR $=[(D_{11}.D_{12}...D_{1n}).(D_{21}.D_{22}...D_{2n}). ...(D_{n1}.D_{n2}.D_{nn})]^{\frac{1}{n^2}} $ <br><br>
# $n = 4 \quad \quad $ No. of Conductors
# $ D{11}= {D22} = D{33} =D{44} = 0.7788 * r \quad \quad $ Self GMR <br>
# $ D_{12} = D_{13} = D_{14} = 2r$<br>
# $ D_{21} = D_{23} = D_{24} = 2r$<br>
# $ D_{31} = D_{32} = D_{34} = 2r$<br>
# $ D_{41} = D_{42} = D_{43} = 2r$<br><br><br>
#
# GMR $=[(D_{11}.D_{12}.D_{13}.D_{14}).(D_{21}.D_{22}.D_{23}.D_{24}).(D_{31}.D_{32}.D_{33}.D_{34}).(D_{41}.D_{42}.D_{43}.D_{44})]^{\frac{1}{4^2}} $ <br><br>
# GMR $=[(0.7788r.2r.2r.2r).(0.7788r.2r.2r.2r).(0.7788r.2r.2r.2r).(0.7788r.2r.2r.2r)]^{\frac{1}{16}} $ <br><br>
# GMR $=[(0.7788r.2r.2r.2r)^{4}]^{\frac{1}{16}} $ <br><br>
# GMR $=[(6.2304*r*r*r*r)]^{\frac{4}{16}} $ <br><br>
# GMR $=[(6.2304*r^4)]^{\frac{1}{4}} $ <br><br>
# GMR $=1.5798977567841632 * r $ <br><br>

# %% [markdown]
# ## CONFIGURATION 2

# %% [markdown]
# seven strands with the following configuration. The six strands forming the outer ring are symmetrically layed out and have a radius $r$. The Concentric strand has radius $2r$
# ![image.png](attachment:image.png)

# %% [markdown]
# Self GMR <br>
# $D_{11} = 0.7788 * 2r = 1.5576r$ <br>
# $D_{22}=D_{33}=D_{44}=D_{55}=D_{66}= D_{77}= 0.7788r$ <br><br>
#
# GMR from centre conductor to other smaller conductor <br>
# $D_{12} = D_{13} =D_{14} =D_{15} =D_{16} = D_{17} = 3r$ <br><br>
#
# Connecting 2r cirlce radius to all the radius of r circle. The angle between $= \frac{360}{6} =60 \degree$<br>
# $c^{2} = a^{2} + b^{2} -2ab\cos\angle abc$ <br>
# $c^{2}= (3r)^2 + (3r)^2  - 2(3r)(3r)\cos (60\degree)$<br>
# $c = 3r$<br>
#
# Distance between r circle and next to next r circle is <br>
# $c^{2} = a^{2} + b^{2} -2ab\cos\angle abc$ <br>
# $c^{2}= (3r)^2 + (3r)^2  - 2(3r)(3r)\cos (120\degree)$<br>
# $c = 3\sqrt{3}r$<br>
#
#
# GMR from smaller conductors to other smaller conductors <br>
# $D_{21} = 3r$ <br>
# $D_{23} = 3r$ <br>
# $D_{24} = 3\sqrt{3}r$ <br>
# $D_{25} = 6r$ <br>
# $D_{26} = 3\sqrt{3}r$ <br>
# $D_{27} = 3r$ <br><br>
#
# GMR $=[(D_{11}.D_{12}...D_{1n}).(D_{21}.D_{22}...D_{2n}). ...(D_{n1}.D_{n2}.D_{nn})]^{\frac{1}{n^2}} $ <br><br>
# $n = 7 \quad \quad $ No. of Conductors <br><br>
#
# GMR $=[(D_{11}.D_{12}...D_{17}).(D_{21}.D_{22}...D_{27}). ...(D_{71}.D_{72}.D_{77})]^{\frac{1}{7^2}} $ <br><br>
#
# GMR $=[(0.7788.2r.3r.3r.3r.3r.3r.3r).(0.7788r.3r.3r.3\sqrt{3}r.3\sqrt{3}r.6r.3r). ...(0.7788r.3r.3r.3\sqrt{3}r.3\sqrt{3}r.6r.3r)]^{\frac{1}{49}} $ <br><br>
#
# GMR $=[1.7742376713476714 . 10^{24}.r^{49}]^{\frac{1}{49}} $ <br>
# GMR $ = 3.1251998281598032r$

# %%
r = 1
n=7
D11 = 0.7788 * 2 *r # Self GMR
D22 = D33 = D44 = D55 = D66 = D77 = 0.7788 *r 
D12 = D13 = D14 = D15 = D16 = D17 = 3 * r
D21 = D27 = D23 = 3 * r
D24 = D26 = (3 ** (1/2)) * 3 * r 
D25 = 6 * r

# %%
r_circle = math.pow((D21*D22*D23*D24*D25*D26*D27),6) # GMR of 6 r radius circle
r_circle
# Out:
# 1.562529873742368e+21

# %%
r2_circle = D11 * (math.pow(D12,6)) # GMR of 2r circle
r2_circle
# Out:
# 1135.4904000000001

# %%
GMR_2 = math.pow( (r2_circle *  r_circle), 1/(n**2))

# %%
GMR_3

# %%
GMR_2r = 1
n=7
D11 = 0.7788  *r # Self GMR
D22 = D33 = D44 = D55 = D66 = D77 = 0.7788 *r 
D12 = D13 = D14 = D15 = D16 = D17 = 2 * r
D21 = D27 = D23 = 2 * r
D24 = D26 = (3 ** (1/2)) * 2 * r 
D25 = 4 * r

# %%
r2_circle = D11 * (math.pow(D12,6)) # GMR of 2r circle
r2_circle
# Out:
# 49.8432

# %%
r_circle = math.pow((D21*D22*D23*D24*D25*D26*D27),6) # GMR of 6 r radius circle
r_circle
# Out:
# 715390227608557.0

# %%
GMR_3 = math.pow( (r2_circle *  r_circle), 1/(n**2))

# %%
GMR_3
# Out:
# 2.320088876237401
